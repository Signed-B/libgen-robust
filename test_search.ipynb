# %%
from src.libgen_bulk import search
from src.libgen_bulk import select

# %%
mirror="https://libgen.vg"

# %%
req = search.LibgenSearch(
    query="Heartsong TJ Klune", 
    mirror=mirror,
    search_field=[search.SearchField.TITLE, search.SearchField.AUTHORS],
    search_objects=[search.SearchObject.FILES],
    search_topics=[search.SearchTopic.LIBGEN, search.SearchTopic.FICTION]
)
print(req.build_search_url())
list = req.execute()
list
# Out:
# https://libgen.vg/index.php?req=Heartsong+TJ+Klune&columns%5B%5D=t&columns%5B%5D=a&objects%5B%5D=f&topics%5B%5D=l&topics%5B%5D=f&res=100&filesuns=all
# [Book(id='100152331', title='Green Creek 3', author='TJ Klune', year='None', extension='pdf', date_added='2023-07-11', date_last_modified='2023-07-16'),
#  Book(id='102322529', title='Green Creek 3', author='TJ Klune', year='None', extension='mobi', date_added='2023-07-13', date_last_modified='2023-07-19'),
#  Book(id='102813508', title='Green Creek 3', author='TJ Klune', year='2019', extension='pdf', date_added='2023-07-13', date_last_modified='2023-07-20'),
#  Book(id='103713723', title='Green Creek 3', author='Tj Klune', year='2021', extension='epub', date_added='2023-08-29', date_last_modified='2023-10-03'),
#  Book(id='112110494', title='Green Creek #3', author='TJ Klune', year='2025', extension='epub', date_added='2025-12-15', date_last_modified='2025-12-15'),
# ...

# %%
selector = select.Selector(mirror=mirror, count=5)
books = selector.select("Think and Grow Rich", "Napoleon Hill", year=None, table=list)
books
# Out:
# [Book(id='105475272', title='THINK AND GROW RICH', author='Napoleon Hill', year='2019', extension='epub', date_added='2024-08-17', date_last_modified='2024-09-07'),
#  Book(id='92297696', title='think and grow rich', author='Napoleon Hill', year='2010', extension='djvu', date_added='2014-10-05', date_last_modified='2021-10-06'),
#  Book(id='104436618', title='Think and Grow Rich', author='Napoleon Hill', year='2010', extension='epub', date_added='2024-02-24', date_last_modified='2024-04-27'),
#  Book(id='91620635', title='Think and Grow Rich', author='Napoleon Hill', year='2002', extension='pdf', date_added='2011-06-04', date_last_modified='2021-09-30'),
#  Book(id='93457588', title='Think and Grow Rich!', author='Napoleon Hill', year='1938', extension='epub', date_added='2020-02-15', date_last_modified='2020-02-15')]

# %%
for book in books:
    print(book.download_page_link)
# Out:
# https://libgen.vg/ads.php?md5=c7a8cb0890ddeeafeae8057c45b5a989
# https://libgen.vg/ads.php?md5=c2e4784fb1081c7ec98e8826b3a8ccac
# https://libgen.vg/ads.php?md5=1f64a81ff740f5a80ba131b7818e8bf8
# https://libgen.vg/ads.php?md5=949d61d2e77ceb511b64ba808e274e32
# https://libgen.vg/ads.php?md5=1e35d05a6e64f638b260f9b52315a925
