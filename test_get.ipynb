# %%
from src.libgen_bulk.get import Getter

# %%
getter = Getter(
    score_threshold=7, 
    mirror="https://libgen.li", 
    output_dir="./data",
)
path = getter.get("Deathly Hallows", "JK Rowling", None)
# Out:
# Error during search page retrieval: Request to https://libgen.li timed out
# Retryable error during search:title (attempt 1/5): Request to https://libgen.li timed out; waiting 1.12s
